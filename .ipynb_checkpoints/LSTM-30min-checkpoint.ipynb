# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import hashlib
import json
from datetime import datetime, timedelta

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100.0

print("TensorFlow:", tf.__version__)
print("Using CUDA GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# Using CUDA GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
end_date = datetime.now()
start_date = end_date - timedelta(days=60)
# start_date = "2023-07-15"
horizon = "30m"

print("Start date:", start_date)
print("End date:", end_date)
# Out:
# Start date: 2025-10-02 20:23:20.772648
# End date: 2025-12-01 20:23:20.772648

# %%
gold = yf.download("GC=F", start = start_date, end = end_date, interval = horizon, auto_adjust = False)
silver = yf.download("SI=F", start = start_date, end = end_date, interval = horizon,auto_adjust = False)
cad = yf.download("CADUSD=X", start = start_date, end = end_date, interval = horizon, auto_adjust = False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1832 entries, 2025-10-03 00:00:00+00:00 to 2025-12-01 18:00:00+00:00
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, GC=F)  1832 non-null   float64
#  1   (Close, GC=F)      1832 non-null   float64
#  2   (High, GC=F)       1832 non-null   float64
#  3   (Low, GC=F)        1832 non-null   float64
#  4   (Open, GC=F)       1832 non-null   float64
#  5   (Volume, GC=F)     1832 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 100.2 KB

# %%
silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1832 entries, 2025-10-03 00:00:00+00:00 to 2025-12-01 18:00:00+00:00
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, SI=F)  1832 non-null   float64
#  1   (Close, SI=F)      1832 non-null   float64
#  2   (High, SI=F)       1832 non-null   float64
#  3   (Low, SI=F)        1832 non-null   float64
#  4   (Open, SI=F)       1832 non-null   float64
#  5   (Volume, SI=F)     1832 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 100.2 KB

# %%
cad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1990 entries, 2025-10-02 19:00:00+00:00 to 2025-12-01 18:00:00+00:00
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, CADUSD=X)  1990 non-null   float64
#  1   (Close, CADUSD=X)      1990 non-null   float64
#  2   (High, CADUSD=X)       1990 non-null   float64
#  3   (Low, CADUSD=X)        1990 non-null   float64
#  4   (Open, CADUSD=X)       1990 non-null   float64
#  5   (Volume, CADUSD=X)     1990 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 108.8 KB

# %%
def asset_heatmap(df, asset_name):
    plt.figure(figsize=(7, 5))
    sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
    plt.title(f"{asset_name} Feature Correlation Heatmap")
    plt.show()

# %%
asset_heatmap(gold, "Gold")
asset_heatmap(silver, "Silver")
asset_heatmap(cad, "CAD")

# %%
gold = gold[["Close"]].rename(columns={"Close": "Gold"})
silver = silver[["Close"]].rename(columns={"Close": "Silver"})
cad = cad[["Close"]].rename(columns={"Close": "CAD"})

# %%
all_prices = gold.join([silver, cad], how="outer")
all_prices.to_csv("prices_with_null.csv")

# %%
all_prices = all_prices.ffill().bfill() # forward-fill + backward-fill to deal with missing values
all_prices.to_csv("prices.csv")

# %%
all_prices.head()
# Out:
# Price                        Gold     Silver       CAD
# Ticker                       GC=F       SI=F  CADUSD=X
# Datetime
# 2025-10-02 19:00:00+00:00  3882.5  46.720001  0.716435
# 2025-10-02 19:30:00+00:00  3882.5  46.720001  0.716261
# 2025-10-02 20:00:00+00:00  3882.5  46.720001  0.716127
# 2025-10-02 20:30:00+00:00  3882.5  46.720001  0.716025
# 2025-10-02 21:00:00+00:00  3882.5  46.720001  0.716050

# %%
all_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2005 entries, 2025-10-02 19:00:00+00:00 to 2025-12-01 18:00:00+00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Gold, GC=F)     2005 non-null   float64
#  1   (Silver, SI=F)   2005 non-null   float64
#  2   (CAD, CADUSD=X)  2005 non-null   float64
# dtypes: float64(3)
# memory usage: 62.7 KB

# %%
all_prices.describe()
# Out:
# Price          Gold       Silver          CAD
# Ticker         GC=F         SI=F     CADUSD=X
# count   2005.000000  2005.000000  2005.000000
# mean    4095.177012    49.903087     0.713142
# std      106.121516     2.351265     0.002501
# min     3863.199951    45.665001     0.707269
# 25%     4012.000000    48.110001     0.711764
# 50%     4078.899902    49.470001     0.713165
# 75%     4167.799805    51.209999     0.714812
# max     4394.299805    59.200001     0.719746

# %% [markdown]
# ## feature engineering

# %%
# # adding features that make more sense than raw data
# all_prices["Gold_ret"] = all_prices["Gold"].pct_change()
# all_prices["Silver_ret"] = all_prices["Silver"].pct_change()
# all_prices["CAD_ret"] = all_prices["CAD"].pct_change()

# all_prices["Gold_ma"] = all_prices["Gold"].rolling(5).mean()
# all_prices["Silver_ma"] = all_prices["Silver"].rolling(5).mean()
# all_prices["CAD_ma"] = all_prices["CAD"].rolling(5).mean()

# all_prices = all_prices.dropna()

# %%
# all_prices.head()

# %%
all_prices.to_csv("prices_engineered.csv")

# %%
# scaler = MinMaxScaler()
# scaled = scaler.fit_transform(all_prices)

# scaled_prices = pd.DataFrame(scaled, index=all_prices.index, columns=all_prices.columns)

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(all_prices)

def create_sequences(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i : i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

window = 40
X, y = create_sequences(scaled, window)

train_size = int(len(X)*0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(window, 3)),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(3)
])

model.compile(optimizer="adam", loss="mse", metrics=[tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 40, 128)        │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,171 (465.51 KB)
#  Trainable params: 119,171 (465.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
earlystop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

reduceLR = tf.keras.callbacks.ReduceLROnPlateau(
    factor=0.5, patience=10, min_lr=1e-6
)

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[earlystop, reduceLR],
    verbose=1
)
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0315 - mean_absolute_error: 0.1241 - mean_squared_error: 0.0315 - val_loss: 0.0070 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0070 - learning_rate: 0.0010
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mean_absolute_error: 0.0612 - mean_squared_error: 0.0063 - val_loss: 0.0047 - val_mean_absolute_error: 0.0588 - val_mean_squared_error: 0.0047 - learning_rate: 0.0010
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0048 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0019 - learning_rate: 0.0010
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0040 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0014 - learning_rate: 0.0010
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0036 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0016 - learning_rate: 0.0010
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0034 - val_loss: 0.0016 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0016 - learning_rate: 0.0010
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0032 - val_loss: 0.0012 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 0.0012 - learning_rate: 0.0010
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0028 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0013 - learning_rate: 0.0010
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0029 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0014 - learning_rate: 0.0010
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mean_absolute_error: 0.0395 - mean_squared_error: 0.0028 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0011 - learning_rate: 0.0010
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mean_absolute_error: 0.0383 - mean_squared_error: 0.0026 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284 - val_mean_squared_error: 0.0013 - learning_rate: 0.0010
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0023 - val_loss: 0.0011 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011 - learning_rate: 0.0010
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0023 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0012 - learning_rate: 0.0010
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0358 - mean_squared_error: 0.0023 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0014 - learning_rate: 0.0010
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - mean_squared_error: 0.0022 - val_loss: 0.0012 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012 - learning_rate: 0.0010
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318 - val_mean_squared_error: 0.0017 - learning_rate: 0.0010
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0021 - val_loss: 9.7113e-04 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 9.7113e-04 - learning_rate: 0.0010
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - mean_squared_error: 0.0020 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0010 - learning_rate: 0.0010
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - mean_squared_error: 0.0018 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010 - learning_rate: 0.0010
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0019 - val_loss: 9.4501e-04 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.4501e-04 - learning_rate: 0.0010
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - mean_squared_error: 0.0017 - val_loss: 9.7666e-04 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.7666e-04 - learning_rate: 0.0010
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - mean_squared_error: 0.0017 - val_loss: 9.2541e-04 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 9.2541e-04 - learning_rate: 0.0010
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0016 - val_loss: 8.3008e-04 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 8.3008e-04 - learning_rate: 0.0010
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0294 - mean_squared_error: 0.0016 - val_loss: 8.5684e-04 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 8.5684e-04 - learning_rate: 0.0010
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0015 - val_loss: 8.5281e-04 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 8.5281e-04 - learning_rate: 0.0010
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 9.7579e-04 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 9.7579e-04 - learning_rate: 0.0010
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0014 - val_loss: 7.9719e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 7.9719e-04 - learning_rate: 0.0010
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0014 - val_loss: 9.7745e-04 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.7745e-04 - learning_rate: 0.0010
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0014 - val_loss: 8.8377e-04 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 8.8377e-04 - learning_rate: 0.0010
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 8.0535e-04 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 8.0535e-04 - learning_rate: 0.0010
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0010 - learning_rate: 0.0010
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 7.9544e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 7.9544e-04 - learning_rate: 0.0010
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.4984e-04 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.4984e-04 - learning_rate: 0.0010
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 8.3376e-04 - val_mean_absolute_error: 0.0203 - val_mean_squared_error: 8.3376e-04 - learning_rate: 5.0000e-04
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010 - learning_rate: 5.0000e-04
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - mean_squared_error: 0.0012 - val_loss: 7.6589e-04 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 7.6589e-04 - learning_rate: 5.0000e-04
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0256 - mean_squared_error: 0.0012 - val_loss: 8.6089e-04 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 8.6089e-04 - learning_rate: 5.0000e-04
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - mean_squared_error: 0.0012 - val_loss: 7.4510e-04 - val_mean_absolute_error: 0.0191 - val_mean_squared_error: 7.4510e-04 - learning_rate: 5.0000e-04
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 8.1845e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 8.1845e-04 - learning_rate: 5.0000e-04
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0012 - val_loss: 7.3498e-04 - val_mean_absolute_error: 0.0189 - val_mean_squared_error: 7.3498e-04 - learning_rate: 5.0000e-04
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mean_absolute_error: 0.0249 - mean_squared_error: 0.0011 - val_loss: 7.2932e-04 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 7.2932e-04 - learning_rate: 5.0000e-04
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - mean_squared_error: 0.0011 - val_loss: 7.7772e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 7.7772e-04 - learning_rate: 5.0000e-04
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - mean_squared_error: 0.0011 - val_loss: 7.5098e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 7.5098e-04 - learning_rate: 5.0000e-04
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - mean_squared_error: 0.0011 - val_loss: 7.6511e-04 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 7.6511e-04 - learning_rate: 5.0000e-04
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - mean_squared_error: 0.0012 - val_loss: 8.8312e-04 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 8.8312e-04 - learning_rate: 5.0000e-04
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - mean_squared_error: 0.0011 - val_loss: 8.8496e-04 - val_mean_absolute_error: 0.0211 - val_mean_squared_error: 8.8496e-04 - learning_rate: 5.0000e-04

# %%
y_pred = model.predict(X_test)

# inverse scale
y_test_inv = scaler.inverse_transform(y_test)
y_pred_inv = scaler.inverse_transform(y_pred)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
baseline = scaler.inverse_transform(X_test[:, -1, :]) # last real point

# %%
def plot_asset(i, asset_name):
    plt.figure(figsize=(12,5))
    plt.plot(y_test_inv[:, i], label="Actual", color="blue")
    plt.plot(y_pred_inv[:, i], label="Predicted", color="orange")
    plt.plot(baseline[:, i], label="Baseline", color="magenta")
    plt.title(f"{asset_name} - LSTM 30min")
    plt.xlabel("Time")
    plt.ylabel("Price (USD)")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_asset(0, "Gold")
plot_asset(1, "Silver")
plot_asset(2, "CAD")

# %%
def mae(y, p): return np.mean(np.abs(y-p))
def rmse(y, p): return np.sqrt(np.mean((y-p)**2))
def mape(y, p): return np.mean(np.abs((y-p)/y))*100

assets = ["Gold","Silver","CAD"]
for i in range(3):
    print(assets[i])
    print(" MAE :", mae(y_test_inv[:,i], y_pred_inv[:,i]))
    print(" RMSE:", rmse(y_test_inv[:,i], y_pred_inv[:,i]))
    print(" MAPE:", mape(y_test_inv[:,i], y_pred_inv[:,i]))
    print()
# Out:
# Gold
#  MAE : 11.389614891459921
#  RMSE: 15.776777687967007
#  MAPE: 0.27315634071764344
#
# Silver
#  MAE : 0.5380900628087479
#  RMSE: 0.6806184365972829
#  MAPE: 1.0042687822346903
#
# CAD
#  MAE : 0.0005068437743732947
#  RMSE: 0.0006568673238879998
#  MAPE: 0.07132926634998339

# %%
predict_window = 40

def parse_range(user_input): #format: DD-MM-YYYY; DD-MM-YYYY
   # Example: 10-12-2025; 14-12-2025
    if ";" not in user_input:
        raise ValueError("Invalid format. Use: DD-MM-YYYY; DD-MM-YYYY")

    parts = user_input.split(";")
    if len(parts) != 2:
        raise ValueError("Invalid format. Use: DD-MM-YYYY; DD-MM-YYYY")

    start_str = parts[0].strip()
    end_str   = parts[1].strip()

    try:
        start = datetime.strptime(start_str, "%d-%m-%Y")
        end   = datetime.strptime(end_str, "%d-%m-%Y")
    except:
        raise ValueError("Invalid date. Use exactly this format: DD-MM-YYYY; DD-MM-YYYY")

    return start, end

def user_date():
    while True:
        user_input = input("Enter date range exactly in this format inside the parenthesis, with the start date first (DD-MM-YYYY; DD-MM-YYYY): ")

        try:
            start, end = parse_range(user_input)
            return user_input
        except Exception as e:
            print(f"\nError: {str(e)}\nPlease try again.\n")


def predict_range(date_string, interval="30m"):
    start, end = parse_range(date_string)

    # downloading data to be able to compare with the actual value
    gold = yf.download("GC=F", start=start, end=end, interval=interval, auto_adjust = False)[["Close"]].rename(columns={"Close": "Gold"})
    silver = yf.download("SI=F", start=start, end=end, interval=interval, auto_adjust = False)[["Close"]].rename(columns={"Close": "Silver"})
    cad = yf.download("CADUSD=X", start=start, end=end, interval=interval, auto_adjust = False)[["Close"]].rename(columns={"Close": "CAD"})
    
    
    data = gold.join([silver, cad], how="outer").dropna()

    if data.shape[0] == 0:
        raise ValueError(
            f"No Yahoo Finance data found between {start.date()} and {end.date()} "
            f"for interval='{interval}'. "
            "Try an earlier date range that already has price history."
        )

    scaled_data = scaler.transform(data)

    X_seq = []
    last_seq = scaled[-predict_window:]
    window = np.vstack([scaled[-predict_window:], scaled_data])

    for i in range(len(data)):
        seq = window[i:i+predict_window]
        if seq.shape[0] == predict_window:
            X_seq.append(seq)

    X_seq = np.array(X_seq)

    preds = model.predict(X_seq)
    preds_inv = scaler.inverse_transform(preds)

    data["Gold_pred"], data["Silver_pred"], data["CAD_pred"] = (
        preds_inv[:, 0], preds_inv[:, 1], preds_inv[:, 2]
    )

    return data


def plot_results(df):
    assets = ["Gold", "Silver", "CAD"]
    for asset in assets:
        actual = df[asset].values
        predicted = df[f"{asset}_pred"].values
        
        # baseline: next price = current actual
        baseline = np.roll(actual, 1)
        baseline[0] = actual[0]  

        plt.figure(figsize=(12,5))
        plt.plot(df.index, actual, label=f"{asset} Actual", color="blue")
        plt.plot(df.index, predicted, label=f"{asset} Predicted", color="orange")
        plt.plot(df.index, baseline, label=f"{asset} Baseline", color="magenta")
        
        plt.title(f"{asset} - Actual vs Predicted vs Baseline")
        plt.xlabel("Time and Date")
        plt.ylabel("Price (USD)")
        plt.legend()
        plt.grid(True)
        plt.show()


# 20-11-2025; 28-11-2025
user_range = user_date()
user_df = predict_range(user_range, interval="30m")
plot_results(user_df)
# Out:
# Enter date range exactly in this format inside the parenthesis, with the start date first (DD-MM-YYYY; DD-MM-YYYY): 20-11-2025; 28-11-2025
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
user_df.head()
# Out:
# Price                             Gold     Silver       CAD    Gold_pred  \
# Ticker                            GC=F       SI=F  CADUSD=X
# Datetime
# 2025-11-20 05:00:00+00:00  4068.899902  51.000000  0.711389  4244.288086
# 2025-11-20 05:30:00+00:00  4065.100098  50.895000  0.711263  4197.478027
# 2025-11-20 06:00:00+00:00  4061.600098  50.884998  0.711364  4142.226074
# 2025-11-20 06:30:00+00:00  4066.899902  50.860001  0.711420  4094.190918
# 2025-11-20 07:00:00+00:00  4061.399902  50.845001  0.711318  4057.395996
#
# Price                     Silver_pred  CAD_pred
# Ticker
# Datetime
# 2025-11-20 05:00:00+00:00   57.190903  0.715429
# 2025-11-20 05:30:00+00:00   56.037453  0.714558
# 2025-11-20 06:00:00+00:00   54.508057  0.713522
# 2025-11-20 06:30:00+00:00   53.017632  0.712619
# 2025-11-20 07:00:00+00:00   51.875107  0.711970

# %%
# 28-11-2025; 01-12-2025
user_range = user_date()
user_df = predict_range(user_range, interval="30m")
user_df.head()
plot_results(user_df)
# Out:
# Enter date range exactly in this format inside the parenthesis, with the start date first (DD-MM-YYYY; DD-MM-YYYY): 28-11-2025; 01-12-2025
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
user_df.head()
# Out:
# Price                             Gold     Silver       CAD    Gold_pred  \
# Ticker                            GC=F       SI=F  CADUSD=X
# Datetime
# 2025-11-28 14:30:00+00:00  4233.500000  55.799999  0.715308  4244.287598
# 2025-11-28 15:00:00+00:00  4232.200195  55.799999  0.716173  4230.682617
# 2025-11-28 15:30:00+00:00  4239.299805  56.180000  0.717340  4212.772949
# 2025-11-28 16:00:00+00:00  4244.799805  56.314999  0.715820  4197.758301
# 2025-11-28 16:30:00+00:00  4242.100098  56.450001  0.715533  4188.492676
#
# Price                     Silver_pred  CAD_pred
# Ticker
# Datetime
# 2025-11-28 14:30:00+00:00   57.190910  0.715429
# 2025-11-28 15:00:00+00:00   56.915295  0.715290
# 2025-11-28 15:30:00+00:00   56.573566  0.715312
# 2025-11-28 16:00:00+00:00   56.351768  0.715607
# 2025-11-28 16:30:00+00:00   56.145351  0.715768
