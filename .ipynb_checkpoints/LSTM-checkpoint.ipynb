# %% [markdown]
# ## plan:
# - learn the basics of gold, silver and CAD prices
# - try a simple linear regression just to say that we tried it
# - experiment with LSTMs
# - account for inflation and other economic factors that may be relevant
# - scrape news headlines and use them for sentiment analysis

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import hashlib
import json
from datetime import datetime, timedelta

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import layers, models

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100.0

print("TensorFlow:", tf.__version__)
print("Using GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
end_date = datetime.now()
start_date = end_date - timedelta(days=60)

print("Start date:", start_date)
print("End date:", end_date)
# Out:
# Start date: 2025-09-30 23:44:38.384147
# End date: 2025-11-29 23:44:38.384147

# %%
# my_end = "2025-11-20" # so I can use the days after that for testing
# end_date = datetime.strptime(my_end, "%Y-%m-%d")
# start_date = "2025-10-01"

gold = yf.download("GC=F", start = start_date, end = end_date, interval = "30m", auto_adjust = False)
silver = yf.download("SI=F", start = start_date, end = end_date, interval = "30m",auto_adjust = False)
cad = yf.download("CADUSD=X", start = start_date, end = end_date, interval = "30m", auto_adjust = False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
gold = gold[["Close"]].rename(columns={"Close": "Gold"})
silver = silver[["Close"]].rename(columns={"Close": "Silver"})
cad = cad[["Close"]].rename(columns={"Close": "CAD"})

# %%
all_prices = gold.join([silver, cad], how="outer")
all_prices.to_csv("prices_with_null.csv")

# %%
all_prices = all_prices.ffill().bfill() # forward-fill + backward-fill to deal with missing values
all_prices.to_csv("prices.csv")

# %%
all_prices.head()
# Out:
# Price                             Gold Silver       CAD
# Ticker                            GC=F   SI=F  CADUSD=X
# Datetime
# 2025-09-30 22:30:00+00:00  3889.699951  47.32  0.718370
# 2025-09-30 23:00:00+00:00  3889.699951  47.32  0.718396
# 2025-09-30 23:30:00+00:00  3889.699951  47.32  0.718200
# 2025-10-01 00:00:00+00:00  3889.699951  47.32  0.718066
# 2025-10-01 00:30:00+00:00  3889.699951  47.32  0.718045

# %%
all_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2055 entries, 2025-09-30 22:30:00+00:00 to 2025-11-28 23:00:00+00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Gold, GC=F)     2055 non-null   float64
#  1   (Silver, SI=F)   2055 non-null   float64
#  2   (CAD, CADUSD=X)  2055 non-null   float64
# dtypes: float64(3)
# memory usage: 64.2 KB

# %%
all_prices.describe()
# Out:
# Price          Gold       Silver          CAD
# Ticker         GC=F         SI=F     CADUSD=X
# count   2055.000000  2055.000000  2055.000000
# mean    4083.014020    49.637304     0.713286
# std      109.557770     2.088464     0.002610
# min     3851.800049    45.665001     0.707269
# 25%     4004.000000    47.970001     0.711812
# 50%     4072.000000    48.880001     0.713267
# 75%     4153.649902    51.027500     0.714944
# max     4394.299805    57.080002     0.719746

# %% [markdown]
# ## feature engineering

# %%
# adding features that make more sense than raw data
all_prices["Gold_ret"] = all_prices["Gold"].pct_change()
all_prices["Silver_ret"] = all_prices["Silver"].pct_change()
all_prices["CAD_ret"] = all_prices["CAD"].pct_change()

all_prices["Gold_ma"] = all_prices["Gold"].rolling(5).mean()
all_prices["Silver_ma"] = all_prices["Silver"].rolling(5).mean()
all_prices["CAD_ma"] = all_prices["CAD"].rolling(5).mean()

all_prices = all_prices.dropna()

# %%
all_prices.head()
# Out:
# Price                             Gold Silver       CAD Gold_ret Silver_ret  \
# Ticker                            GC=F   SI=F  CADUSD=X
# Datetime
# 2025-10-01 00:30:00+00:00  3889.699951  47.32  0.718045      0.0        0.0
# 2025-10-01 01:00:00+00:00  3889.699951  47.32  0.718174      0.0        0.0
# 2025-10-01 01:30:00+00:00  3889.699951  47.32  0.718231      0.0        0.0
# 2025-10-01 02:00:00+00:00  3889.699951  47.32  0.718040      0.0        0.0
# 2025-10-01 02:30:00+00:00  3889.699951  47.32  0.718184      0.0        0.0
#
# Price                       CAD_ret      Gold_ma Silver_ma    CAD_ma
# Ticker
# Datetime
# 2025-10-01 00:30:00+00:00 -0.000029  3889.699951     47.32  0.718215
# 2025-10-01 01:00:00+00:00  0.000180  3889.699951     47.32  0.718176
# 2025-10-01 01:30:00+00:00  0.000079  3889.699951     47.32  0.718143
# 2025-10-01 02:00:00+00:00 -0.000266  3889.699951     47.32  0.718111
# 2025-10-01 02:30:00+00:00  0.000201  3889.699951     47.32  0.718135

# %%
all_prices.to_csv("prices_engineered.csv")

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(all_prices)

scaled_prices = pd.DataFrame(scaled, index=all_prices.index, columns=all_prices.columns)

# %% [markdown]
# ## LSTM

# %%
window = 20

def create_sequences(data, sequence):
    X = [] 
    y = []
    for i in range(len(data) - sequence):
        X.append(data[i : i + sequence])
        y.append(data[i + sequence, :3]) # predict gold, silver, cad
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_prices.values, window)

# %%
split = int(len(X) * 0.8)
X_train, X_val = X[:split], X[split:]
y_train, y_val = y[:split], y[split:]

# %%
print(y_train.shape)
print(y_val.shape)
# Out:
# (1624, 3)
# (407, 3)

# %%
model = models.Sequential([
    layers.Input(shape=(window, scaled_prices.shape[1])),
    layers.LSTM(64, return_sequences=True),
    layers.LSTM(32),
    layers.Dense(3)
])

model.compile(optimizer="adam", loss="mse")

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=32
)
# Out:
# Epoch 1/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0148 - val_loss: 0.0068
# Epoch 2/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 3/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 4/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 5/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 6/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 7/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 8/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 9/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 10/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 11/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 12/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4113e-04 - val_loss: 0.0013
# Epoch 13/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3836e-04 - val_loss: 9.6228e-04
# Epoch 14/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0817e-04 - val_loss: 0.0011
# Epoch 15/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4401e-04 - val_loss: 9.9382e-04
# Epoch 16/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9896e-04 - val_loss: 0.0013
# Epoch 17/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7718e-04 - val_loss: 9.2066e-04
# Epoch 18/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6843e-04 - val_loss: 9.2360e-04
# Epoch 19/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1609e-04 - val_loss: 8.7541e-04
# Epoch 20/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0716e-04 - val_loss: 0.0011

# %%
# predicting one step ahead then appending that prediction into the sequence
def walk_forward_predict(model, X, df, seq_len=20, steps=20):
    preds = []
    current_seq = X[-1]  
    F = df.shape[1] 

    for _ in range(steps):
        pred_scaled = model.predict(current_seq[np.newaxis, :, :])[0]  
        new_row = np.zeros(F)
        new_row[0:3] = pred_scaled 
        new_row[3:] = current_seq[-1, 3:]
        
        # shifting window forward
        current_seq = np.vstack([current_seq[1:], new_row])

        preds.append(pred_scaled)

    return np.array(preds)

# %%
scaled_future_preds = walk_forward_predict(
    model,
    X_val,
    df=scaled_prices,
    seq_len=window,
    steps=20
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
steps = scaled_future_preds.shape[0]
extra = scaled_prices.shape[1] - 3

# padding to full dimension for inverse scaling
padded = np.hstack([
    scaled_future_preds,
    np.zeros((steps, extra))
])

future_full = scaler.inverse_transform(padded)

future_gold  = future_full[:, 0]
future_silver = future_full[:, 1]
future_cad    = future_full[:, 2]

# %%
actual_scaled = y_val[:20]

extra = scaled_prices.shape[1] - 3
actual_padded = np.hstack([
    actual_scaled,
    np.zeros((actual_scaled.shape[0], extra))
])

actual_full = scaler.inverse_transform(actual_padded)

actual_gold  = actual_full[:, 0]
actual_silver = actual_full[:, 1]
actual_cad    = actual_full[:, 2]

# %%
# persistence baseline
baseline_gold  = np.roll(actual_gold, 1)
baseline_silver = np.roll(actual_silver, 1)
baseline_cad    = np.roll(actual_cad, 1)

baseline_gold[0] = actual_gold[0]
baseline_silver[0] = actual_silver[0]
baseline_cad[0] = actual_cad[0]

# %%
import matplotlib.pyplot as plt
import numpy as np

# gold
plt.figure(figsize=(14,6))
plt.plot(actual_gold, color="blue", label="Actual Gold")
plt.plot(future_gold, color="orange", label="Predicted Gold")
plt.plot(baseline_gold, color="magenta", label="Baseline Gold")
plt.title("Gold Price Prediction (30m)")
plt.xlabel("Time (Validation Steps)")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# silver
plt.figure(figsize=(14,6))
plt.plot(actual_silver, color="blue", label="Actual Silver")
plt.plot(future_silver, color="orange", label="Predicted Silver")
plt.plot(baseline_silver, color="magenta", label="Baseline Silver")
plt.title("Silver Price Prediction (30m)")
plt.xlabel("Time (Validation Steps)")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# CAD
plt.figure(figsize=(14,6))
plt.plot(actual_cad, color="blue", label="Actual CAD/USD")
plt.plot(future_cad, color="orange", label="Predicted CAD/USD")
plt.plot(baseline_cad, color="magenta", label="Baseline CAD/USD")
plt.title("CAD/USD Prediction (30m)")
plt.xlabel("Time (Validation Steps)")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()
