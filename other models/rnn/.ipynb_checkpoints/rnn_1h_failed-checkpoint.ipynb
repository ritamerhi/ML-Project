# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt
import yfinance as yf

# %%
gold_1h = yf.download("GC=F", period='729d', interval="1h")
gold_1h.columns = gold_1h.columns.droplevel(1)

silver_1h = yf.download("SI=F", period="730d", interval="1h")
silver_1h.columns = silver_1h.columns.droplevel(1)

cad_1h = yf.download("CADUSD=X", period="730d", interval="1h")
cad_1h.columns = cad_1h.columns.droplevel(1)
# Out:
# /tmp/ipykernel_109755/1067205701.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gold_1h = yf.download("GC=F", period='730d', interval="1h")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GC=F']: ImpersonateError('Impersonating chrome136 is not supported')
# /tmp/ipykernel_109755/1067205701.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   silver_1h = yf.download("SI=F", period="730d", interval="1h")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SI=F']: ImpersonateError('Impersonating chrome136 is not supported')
# /tmp/ipykernel_109755/1067205701.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cad_1h = yf.download("CADUSD=X", period="730d", interval="1h")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CADUSD=X']: ImpersonateError('Impersonating chrome136 is not supported')
